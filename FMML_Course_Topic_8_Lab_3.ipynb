# %% [markdown]
# <a href="https://colab.research.google.com/github/monikagithub1234/Fmmllabs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 15:55:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   202MB/s    in 0.3s
#
# 2024-03-29 15:55:52 (202 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3880 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 211    1504.00641v1  A grand challenge in machine learning is the d...  stat
# 6938   1707.07938v1  The paper deals with regression problems, in w...  stat
# 22926  1711.00799v2  Modeling sequential data has become more and m...  stat
# 21998   1310.4375v3  We present new algorithms to compute the mean ...  stat
# 14002  1704.04777v1  In this paper, we propose a Hybrid Ant Colony ...    cs
# ...             ...                                                ...   ...
# 6121   1607.08194v4  Convolutional neural networks (CNN) have led t...  stat
# 28543  1707.00381v2  In this paper we present a novel joint approac...    cs
# 21305  1712.03223v1  Feature selection is an important preprocessin...    cs
# 22499  1610.03113v2  We derive a novel variational expectation maxi...  stat
# 3499   1709.04836v1  We revisit the problem of robust principal com...  stat
#
#                                                    title  year  \
# 211              A Probabilistic Theory of Deep Learning  2015
# 6938   Error Bounds for Piecewise Smooth and Switchin...  2017
# 22926  Deep Recurrent Gaussian Process with Variation...  2017
# 21998        Fast Computation of Wasserstein Barycenters  2013
# 14002  A Hybrid ACO Algorithm for the Next Release Pr...  2017
# ...                                                  ...   ...
# 6121   Convolutional Neural Networks Analyzed via Con...  2016
# 28543  Joint Pose and Principal Curvature Refinement ...  2017
# 21305  S-Shaped vs. V-Shaped Transfer Functions for A...  2017
# 22499     Truncated Variational Expectation Maximization  2016
# 3499   Informed Non-convex Robust Principal Component...  2017
#
#                                                 keywords
# 211    [challenge, development, computational, algori...
# 6938   [regression, nonsmooth, different, operating, ...
# 22926  [sequential, important, applications, autonomo...
# 21998  [algorithms, empirical, probability, transport...
# 14002  [optimization, algorithm, requirement, enginee...
# ...                                                  ...
# 6121   [convolutional, theoretical, understanding, al...
# 28543  [optimising, curvature, alignment, implementat...
# 21305  [selection, important, preprocessing, classifi...
# 22499  [variational, expectation, maximization, trunc...
# 3499   [principal, component, information, optimizati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 211      [challenge, development, computational, algori...
# 6938     [regression, nonsmooth, different, operating, ...
# 22926    [sequential, important, applications, autonomo...
# 21998    [algorithms, empirical, probability, transport...
# 14002    [optimization, algorithm, requirement, enginee...
#                                ...
# 35556    [carefully, overspecification, axiomatized, th...
# 1878     [structured, prediction, searching, combinator...
# 22580    [sinusoidal, inference, inference, performing,...
# 6442     [dimensionality, reduction, algorithms, retain...
# 30915    [efficient, algorithm, segmenting, combining, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8799 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6e390521-6628-40ed-b8fc-ab1ebcb10430" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e390521-6628-40ed-b8fc-ab1ebcb10430")) {                    Plotly.newPlot(                        "6e390521-6628-40ed-b8fc-ab1ebcb10430",                        [{"x":["variation","discriminative","developing","algorithms","outperform","fundamental","pronunciation","capabilities","routinely","framework","architectures","challenge","inference","orientation","understanding","explicitly","probabilistic","intuitions","providing","recognition","complicated","rendering","improvement","shortcomings","analyzing","computational","development","convolutional","perceptual","generative","principled","synthesizing","successes","switching","complexities","deterministically","classifier","different","specifically","considers","partition","piecewise","particular","applications","convergence","rademacher","regression","arbitrary","nonsmooth","partitioning","performed","derivation","functions","component","operating","following","generalization","decomposition","dependency","optimizing","prediction","experimental","important","uncertainty","variational","distribution","introduce","distributed","variationally","furthermore","resulting","structure","propagate","recurrent","autonomous","therefore","approximation","evaluation","forecasting","complexity","integrate","unsupervised","sequential","barycenter","minimizes","computation","subgradients","empirical","resolution","probability","regularizer","implementation","visualize","clustering","extending","barycenters","transport","gradients","constrained","objective","considerably","wasserstein","distances","definition","subgradient","neighborhood","engineering","traditional","approximately","optimization","algorithm","solutions","construction","selection","determine","instances","information","experiments","simulated","construct","artificial","dependencies","outperforms","requirement","constraints","pheromone","extensively","incorporated","universal","increasing","appropriately","computable","characteristics","adversary","significantly","countably","influence","performing","available","conclusion","substitution","identification","appearing","identifier","combination","reference","extraction","segmentation","annotation","annotations","subsequently","beneficial","corrected","demonstrates","additional","benchmarks","unordered","conceptually","voxelized","importance","computations","unpooling","efficiency","computationally","renderings","effectiveness","surpasses","lightweight","efficient","attracted","extension","developed","community","technique","improvements","complexification","performance","nonlinearities","attention","advantage","operators","significant","successfully","wirtinger","knowledge","nonlinear","simplifies","associated","processing","considered","techniques","identifying","gaussianity","correspond","impulsive","distorted","coefficients","destructive","conditions","innovative"],"y":[69,88,60,631,100,94,3,45,4,519,113,143,198,25,150,79,168,1,84,379,33,15,129,15,62,272,120,367,23,113,28,14,6,11,15,3,152,740,190,29,21,11,314,405,115,6,117,86,0,13,132,9,206,104,18,90,117,66,52,45,244,405,365,74,52,218,354,123,1,149,145,306,8,157,60,138,102,278,21,233,44,151,84,1,14,159,2,138,100,178,17,144,9,141,28,0,7,32,73,178,29,3,35,46,1,28,52,163,34,335,817,152,78,161,64,109,677,612,66,95,139,56,246,26,142,4,34,14,49,102,15,9,92,13,282,1,56,68,304,18,4,95,4,6,126,54,111,217,66,61,25,23,11,60,126,103,1,10,1,68,42,1,139,92,4,197,6,13,401,19,104,205,75,225,97,2,884,4,145,94,34,231,94,1,352,54,12,117,273,139,394,67,2,32,2,14,40,4,132,12],"type":"bar"},{"x":["variation","discriminative","developing","algorithms","ou ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Robust</span> <span style='background-color:rgba(0, 255, 0, 0.34743202416918423);'>Representations</span> <span style=''>of</span> <span style=''>Text</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>achieved</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>remarkable</span> <span style=''>results</span> <span style=''>across</span> <span style=''>many</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.4293193717277487);'>processing</span> <span style=''>tasks</span> <span style=''>however</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>attacks</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>based</span> <span style=''>method</span> <span style=''>for</span> <span style=''>limiting</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>to</span> <span style=''>its</span> <span style=''>inputs</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>ideas</span> <span style=''>from</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>thus</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>that</span> <span style=''>are</span> <span style=''>more</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style='background-color:rgba(0, 255, 0, 0.4554973821989528);'>evaluation</span> <span style=''>over</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.696969696969697);'>sentiment</span> <span style=''>datasets</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6131868131868131);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>a</span> <span style=''>baseline</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style=''>dropout</span> <span style=''>method</span> <span style=''>our</span> <span style=''>method</span> <span style=''>achieves</span> <span style=''>superior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>over</span> <span style=''>noisy</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>out</span> <span style=''>of</span> <span style=''>domain</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Indian</span> <span style=''>Buffet</span> <span style=''>process</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convolved</span> <span style=''>multiple</span> <span style=''>output</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <br/><br/><span style=''>Multi</span> <span style=''>output</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>have</span> <span style=''>received</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>during</span> <span style=''>the</span> <span style=''>last</span> <span style=''>few</span> <span style=''>years</span> <span style=''>as</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>to</span> <span style=''>the</span> <span style=''>setup</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>The</span> <span style=''>key</span> <span style=''>point</span> <span style=''>here</span> <span style=''>is</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>design</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>allow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>the</span> <span style=''>outputs</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fulfilling</span> <span style=''>the</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definiteness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requisite</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Alternatives</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coregionalization</span> <span style=''>and</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutions</span> <span style=''>Each</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>demand</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>used</span> <span style=''>to</span> <span style=''>build</span> <span style=''>the</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determination</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <br/><br/><span style=''>Recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sampling</span> <span style=''>patterns</span> <span style=''>have</span> <span style=''>been</span> <span style=''>obtained</span> <span style=''>for</span> <span style=''>finite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completability</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>or</span> <span style=''>tensors</span> <span style=''>given</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>ranks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>scenario</span> <span style=''>where</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>is</span> <span style=''>not</span> <span style=''>given</span> <span style=''>and</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>rank</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>location</span> <span style=''>of</span> <span style=''>sampled</span> <span style=''>entries</span> <span style=''>and</span> <span style=''>some</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>data</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>single</span> <span style=''>view</span> <span style=''>matrix</span> <span style=''>multi</span> <span style=''>view</span> <span style=''>matrix</span> <span style=''>CP</span> <span style=''>tensor</span> <span style=''>tensor</span> <span style=''>train</span> <span style=''>tensor</span> <span style=''>and</span> <span style=''>Tucker</span> <span style=''>tensor</span> <span style=''>For</span> <span style=''>each</span> <span style=''>of</span> <span style=''>these</span> <span style=''>data</span> <span style=''>models</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>when</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>is</span> <span style=''>given</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>these</span> <span style=''>bounds</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministically</span> <span style=''>ie</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>one</span> <span style=''>given</span> <span style=''>that</span> <span style=''>the</span> <span style=''>sampling</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Visualization</span> <span style=''>of</span> <span style=''>Features</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interactions</span> <span style=''>Using</span> <span style=''>Bayesian</span> <span style=''>Forests</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>becoming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>for</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>accurate</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>it</span> <span style=''>is</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>which</span> <span style=''>features</span> <span style=''>and</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>task</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selective</span> <span style=''>Bayesian</span> <span style=''>Forest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <span style=''>that</span> <span style=''>strikes</span> <span style=''>a</span> <span style=''>balance</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>It</span> <span style=''>builds</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parsimonious</span> <span style=''>yet</span> <span style=''>flexible</span> <span style=''>models</span> <span style=''>using</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>samples</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style=''>such</span> <span style=''>models</span> <span style=''>using</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>We</span> <span style=''>build</span> <span style=''>in</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09914407988587731)
# 	representation (0.12874465049928674)
# 	experimental (0.14443651925820256)
# 	knowledge (0.12553495007132667)
# 	information (0.24144079885877318)
# 	segmentation (0.07738944365192582)
# 	detection (0.11982881597717546)
# 	different (0.26390870185449355)
# 	convolutional (0.13088445078459343)
# 	recognition (0.13516405135520684)
#
# Some Statistics words are:
# 	variational (0.10070140280561123)
# 	statistical (0.14779559118236474)
# 	estimation (0.16633266533066132)
# 	distribution (0.1743486973947896)
# 	variables (0.1467935871743487)
# 	algorithm (0.39929859719438876)
# 	theoretical (0.16432865731462926)
# 	inference (0.20190380761523047)
# 	dimensional (0.1908817635270541)
# 	regression (0.18086172344689377)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7b5a75c6-8e86-4447-ad51-279bb529efd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b5a75c6-8e86-4447-ad51-279bb529efd4")) {                    Plotly.newPlot(                        "7b5a75c6-8e86-4447-ad51-279bb529efd4",                        [{"x":["variation","discriminative","developing","algorithms","outperform","fundamental","pronunciation","capabilities","routinely","framework","architectures","challenge","inference","orientation","understanding","explicitly","probabilistic","intuitions","providing","recognition","complicated","rendering","improvement","shortcomings","analyzing","computational","development","convolutional","perceptual","generative","principled","synthesizing","successes","switching","complexities","deterministically","classifier","different","specifically","considers","partition","piecewise","particular","applications","convergence","rademacher","regression","arbitrary","nonsmooth","partitioning","performed","derivation","functions","component","operating","following","generalization","decomposition","dependency","optimizing","prediction","experimental","important","uncertainty","variational","distribution","introduce","distributed","variationally","furthermore","resulting","structure","propagate","recurrent","autonomous","therefore","approximation","evaluation","forecasting","complexity","integrate","unsupervised","sequential","barycenter","minimizes","computation","subgradients","empirical","resolution","probability","regularizer","implementation","visualize","clustering","extending","barycenters","transport","gradients","constrained","objective","considerably","wasserstein","distances","definition","subgradient","neighborhood","engineering","traditional","approximately","optimization","algorithm","solutions","construction","selection","determine","instances","information","experiments","simulated","construct","artificial","dependencies","outperforms","requirement","constraints","pheromone","extensively","incorporated","universal","increasing","appropriately","computable","characteristics","adversary","significantly","countably","influence","performing","available","conclusion","substitution","identification","appearing","identifier","combination","reference","extraction","segmentation","annotation","annotations","subsequently","beneficial","corrected","demonstrates","additional","benchmarks","unordered","conceptually","voxelized","importance","computations","unpooling","efficiency","computationally","renderings","effectiveness","surpasses","lightweight","efficient","attracted","extension","developed","community","technique","improvements","complexification","performance","nonlinearities","attention","advantage","operators","significant","successfully","wirtinger","knowledge","nonlinear","simplifies","associated","processing","considered","techniques","identifying","gaussianity","correspond","impulsive","distorted","coefficients","destructive","conditions","innovative","preprocess","iteratively","filtering","described","recovering","revelation","parametrically","successful","distorting","deconvolution","minimally","transformations","independently","transformer","possibility","transformation","essentially","automatically","designing","verification","comparable","reproducibility","appropriate","difficulties","alignment","landmarks","effective","geometric","implemented","artificially","dynamically","functional","demonstrate","classifiers","classification","versatile","simulation","individual","heterogeneous","topological","disconnected","feedforward","literature","including","pyramidal","manipulation","answering","connected","sufficiently","sufficient","implications","adversarial","activati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonsmooth
# 	barycenters
# 	traintest
# 	ultrametric
# 	irregularly
# 	diagonalise
# 	identifiability
# 	multisensor
# 	convolved
# 	semiparametric
# 	nonparanormal
# 	projectorg
# 	uncorrelated
# 	precludes
# 	discretizations
# 	eigenspaces
# 	embarrassingly
# 	cornerstone
# 	autocorrelation
# 	supernova
# Some words which never appear in Statistics papers:
# 	pheromone
# 	substitution
# 	identifier
# 	complexification
# 	destructive
# 	distorting
# 	transformer
# 	deblurring
# 	programmers
# 	homogeneously
# 	suppressing
# 	histopathological
# 	manifestations
# 	corroborated
# 	cooperate
# 	photographs
# 	photography
# 	rethinking
# 	quadrilateral
# 	plagiarism

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0669201987364294e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
